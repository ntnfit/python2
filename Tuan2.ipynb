# %%
import numpy as np
import pandas as pds
import matplotlib.pyplot as plt
import seaborn as sns

tips=sns.load_dataset("tips")
tips
sns.relplot(x="total_bill",y="tip",data=tips)

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",style="time")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,style="size")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,size="size",sizes=(15,200))

# %%
sns.regplot(x="total_bill",y="tip",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="smoker")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="smoker",col="time",row="sex")

# %% [markdown]
# 1. trực quan dữ liệu để quan sát sự tương quan giữa các biến.
# 2. nguyên lý trực quan cơ bản: màu sắc, kích thước.
# 3. hồi quy -> khôi phục dữ liệu, dự đoán.
#
# Bài tập
# đọc dữ liệu từ file (local,github,...)
# chọn 1 dataset :https://www.kaggle.com/ , thực hiện các bước trên
#
# 4. Thư viện
# - seaborn
# - pandas
# - numpy
# - matplotlib.pyplib
# - scikilearn
# - ôn : list danh sách, dict
